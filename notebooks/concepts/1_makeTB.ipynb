# %% [markdown]
# ### ① 분개장 불러오기

# %%
from pathlib import Path
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)

DATASET_DIR = Path("../../assets/sources/datasets/level1_sample_data")

df = pd.read_csv(DATASET_DIR / "분개장.csv")
df.head()
# Out:
#          전표일자  전표번호   계정코드    계정과목     차변금액     대변금액     거래처        승인일자 프로젝트코드
# 0  2016-01-01     1  53100   지급수수료  832,000        0  1404.0  2016-01-01   0001
# 1  2016-01-01     1  13500  부가세대급금   83,200        0  1404.0  2016-01-01    NaN
# 2  2016-01-01     1  25300    미지급금        0  915,200  1404.0  2016-01-01   0031
# 3  2016-01-01     2  53100   지급수수료  120,340        0  2161.0  2016-01-01   0026
# 4  2016-01-01     2  13500  부가세대급금   12,034        0  2161.0  2016-01-01    NaN

# %%
df['차변금액'] = df['차변금액'].str.replace(',', '').astype('int64')
df['대변금액'] = df['대변금액'].str.replace(',', '').astype('int64')

# %% [markdown]
# ### ② 피벗테이블로 TB만들기

# %% [markdown]
# #### ②-a 피벗으로 합계DF만들기

# %%
selected_cols = ['차변금액', '대변금액']
pivot_df = pd.pivot_table(df, 
    index = ['계정코드', '계정과목'], # 행으로 계정코드, 계정과목
    values = selected_cols,  # 값으로 차변금액, 대변금액
    # columns = ['거래처'], # 열로 거래처
    aggfunc = ['sum'], # 합계
    fill_value = 0, # NaN을 0으로 대체
    margins = True # 합계행/열 추가
)

print(df.info())
pivot_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24237 entries, 0 to 24236
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   전표일자    24237 non-null  object
#  1   전표번호    24237 non-null  int64
#  2   계정코드    24237 non-null  int64
#  3   계정과목    24237 non-null  object
#  4   차변금액    24237 non-null  int64
#  5   대변금액    24237 non-null  int64
#  6   거래처     20426 non-null  float64
#  7   승인일자    24237 non-null  object
#  8   프로젝트코드  13463 non-null  object
# dtypes: float64(1), int64(4), object(4)
# memory usage: 1.7+ MB
# None
#                          sum
#                         대변금액          차변금액
# 계정코드  계정과목
# 10100 현금           323227674     367803972
# 10300 보통예금      116469441606  117268900714
# 10301 보통예금                 0     449982824
# 10400 제예금        10460000000   12995303982
# 10600 기타단기금융상품      14172728             0

# %% [markdown]
# #### ②-b 인덱스 변경

# %%
print(pivot_df.columns)

pivot_df = pivot_df.reindex(['차변금액', '대변금액'], level = 1, axis = 1)

pivot_df
# Out:
# MultiIndex([('sum', '대변금액'),
#             ('sum', '차변금액')],
#            )
#                             sum
#                            차변금액          대변금액
# 계정코드  계정과목
# 10100 현금              367803972     323227674
# 10300 보통예금         117268900714  116469441606
# 10301 보통예금            449982824             0
# 10400 제예금           12995303982   10460000000
# 10600 기타단기금융상품                0      14172728
# ...                         ...           ...
# 95600 지분법  평가  손실    2625267178             0
# 95800 무형자산손상차손        117333334             0
# 96000 잡손실               1492672             0
# 99800 법인세비용           163954200             0
# All                362378393804  362378393804
#
# [160 rows x 2 columns]

# %% [markdown]
# #### ②-c 잔액 칼럼 삽입

# %%
dr_amount = pivot_df['sum']['차변금액']
cr_amount = pivot_df['sum']['대변금액']

pivot_df['차변잔액'] = (dr_amount - cr_amount).clip(lower=0) # 음수는 0으로
pivot_df['대변잔액'] = (cr_amount - dr_amount).clip(lower=0) # 음수는 0으로

pivot_df
# Out:
#                             sum                      차변잔액      대변잔액
#                            차변금액          대변금액
# 계정코드  계정과목
# 10100 현금              367803972     323227674    44576298         0
# 10300 보통예금         117268900714  116469441606   799459108         0
# 10301 보통예금            449982824             0   449982824         0
# 10400 제예금           12995303982   10460000000  2535303982         0
# 10600 기타단기금융상품                0      14172728           0  14172728
# ...                         ...           ...         ...       ...
# 95600 지분법  평가  손실    2625267178             0  2625267178         0
# 95800 무형자산손상차손        117333334             0   117333334         0
# 96000 잡손실               1492672             0     1492672         0
# 99800 법인세비용           163954200             0   163954200         0
# All                362378393804  362378393804           0         0
#
# [160 rows x 4 columns]

# %% [markdown]
# ### ③ groupby 와 apply 메소드로 TB만들기

# %% [markdown]
# #### ③-cf DataFrameGroupBy 객체 생성

# %%
groupby_df = df.groupby(['계정코드', '계정과목'])

# DataFrameGroupBy 객체의 첫 번째 그룹 출력
key, group = next(iter(groupby_df))

print("Group key:", key)
display(group)


# 각 그룹의 차변금액 합계를 DF로 변환
summary = (
    groupby_df['차변금액']
    .sum()
    .reset_index())

display(
    summary.style.format({
        '차변금액': '{:,.0f}',
    })
)
# Out:
# Group key: (10100, '현금')
#              전표일자  전표번호   계정코드 계정과목      차변금액     대변금액     거래처        승인일자 프로젝트코드
# 41     2016-01-01    99  10100   현금       220        0  1403.0  2016-01-01   0006
# 44     2016-01-01   100  10100   현금         0      110  1403.0  2016-01-01   0006
# 47     2016-01-01   101  10100   현금       500        0  1403.0  2016-01-01   0006
# 50     2016-01-01   102  10100   현금         0      660  1403.0  2016-01-01   0006
# 288    2016-01-05    39  10100   현금  23200000        0     NaN  2016-01-05    NaN
# ...           ...   ...    ...  ...       ...      ...     ...         ...    ...
# 23646  2016-06-30   183  10100   현금         0   281302     NaN  2016-06-30    NaN
# 23669  2016-06-30   189  10100   현금  10000000        0     NaN  2016-06-30    NaN
# 23693  2016-06-30   197  10100   현금         0   996080     NaN  2016-06-30    NaN
# 23707  2016-06-30   197  10100   현금         0   806100     NaN  2016-06-30    NaN
# 23810  2016-06-30   208  10100   현금         0  3000000     NaN  2016-06-30    NaN
#
# [166 rows x 9 columns]
# <style type="text/css">
# </style>
# <table id="T_13736_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >계정코드</th>
#       <th class="col_heading level0 col1" >계정과목</th>
#       <th class="col_heading level0 col2" >차변금액</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_13736_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_13736_row0_col0" class="data row0 col0" >10100</td>
#       <td id="T_13736_row0_col1" class="data row0 col1" >현금</td>
#       <td id="T_13736_row0_col2" class="data row0 col2" >367,803,972</td>
#     </tr>
#     <tr>
#       <th id="T_13736_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_13736_row1_col0" class="data row1 col0" >10300</td>
#       <td id="T_13736_row1_col1" class="data row1 col1" >보통예금</td>
#       <td id="T_13736_row1_col2" class="data row1 col2" >117,268,900,714</td>
#     </tr>
#     <tr>
#       <th id="T_13736_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_13736_row2_col0" class="data row2 col0" >10301</td>
#       <td id="T_13736_row2_col1" class="data row2 col1" >보통예금</td>
#       <td id="T_13736_row2_col2" class="data row2 col2" >449,982,824</td>
#     </tr>
#     <tr>
#       <th id="T_13736_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_13736_row3_col0" class="data row3 col0" >10400</td>
#       <td id="T_13736_row3_col1" class="data row3 col1" >제예금</td>
#       <td id="T_13736_row3_col2" class="data row3 col2" >12,995,303,982</td>
#     </tr>
#     <tr>
#       <th id="T_13736_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_13736_row4_col0" class="data row4 col0" >10600</td>
#       <td id="T_13736_row4_col1" class="data row4 col1" >기타단기금융상품</td>
#       <td id="T_13736_row4_col2" class="data row4 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_13736_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_13736_row5_col0" class="data row5 col0" >10800</td>
#       <td id="T_13736_row5_col1" class="data row5 col1" >외상매출금</td>
#       <td id="T_13736_row5_col2" class="data row5 col2" >37,186,076,368</td>
#     </tr>
#     <tr>
#       <th id="T_13736_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_13736_row6_col0" class="data row6 col0" >10900</td>
#       <td id="T_13736_row6_col1" class="data row6 col1" >대손충당금</td>
#       <td id="T_13736_row6_col2" class="data row6 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_13736_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_13736_row7_col0" class="data row7 col0" >11000</td>
#       <td id="T_13736_row7_col1" class="data row7 col1" >받을어음</td>
#       <td id="T_13736_row7_col2" class="data row7 col2" >90,600,000</td>
#     </tr>
#     <tr>
#       <th id="T_13736_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_13736_row8_col0" class="data row8 col0" >11400</td>
#       <td id="T_13736_row8_col1" class="data row8 col1" >단기대여금</td>
#       <td id="T_13736_row8_col2" class="data row8 col2" >350,000,000</td>
#     </tr>
#     <tr>
#       <th id="T_13736_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_13736_row9_col0" class="data row9 col0" >11600</td>
#       <td id="T_13736_row9_col1" class="data row9 col1" >미수수익</td>
#       <td id="T_13736_row9_col2" class="data row9 col2" >30,003,792</td>
#     </tr>
#     <tr>
#       <th id="T_13736_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_13736_row10_col0" class="data row10 col0" >12000</td>
#       <td id="T_13736_row10_col1" class="data row10 col1" >미수금</td>
#       <td id="T_13736_row10_col2" class="data row10 col2" >1,831,744,666</td>
#     </tr>
#     <tr>
#       <th id="T_13736_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_13736_row11_col0" class="data row11 col0" >13100</td>
#       <td id="T_13736_row11_col1" class="data row11 col1" >선급금</td>
#       <td id="T_13736_row11_col2" class="data row11 col2" >7,530,933,404</td>
#     </tr>
#     <tr>
#       <th id="T_13736_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_13736_row12_col0" class="data row12 col0" >13300</td>
#       <td id="T_13736_row12_col1" class="data row12 col1" >선급비용</td>
#       <td id="T_13736_row12_col2" class="data row12 col2" >80,716,450</td>
#     </tr>
#     <tr>
#       <th id="T_13736_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_13736_row13_col0" class="data row13 col0" >13500</td>
#       <td id="T_13736_row13_col1" class="data row13 col1" >부가세대급금</td>
#       <td id="T_13736_row13_col2" class="data row13 col2" >2,047,958,280</td>
#     </tr>
#     <tr>
#       <th id="T_13736_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_13736_row14_col0" class="data row14 col0" >14100</td>
#       <td id="T_13736_row14_col1" class="data row14 col1" >선납법인세</td>
#       <td id="T_13736_row14_col2" class="data row14 col2" >6,821,140</td>
#     </tr>
#     <tr>
#       <th id="T_13736_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_13736_row15_col0" class="data row15 col0" >14600</td>
#       <td id="T_13736_row15_col1" class="data row15 col1" >상품</td>
#       <td id="T_13736_row15_col2" class="data row15 col2" >4,874,262,536</td>
#     </tr>
#     <tr>
#       <th id="T_13736_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_13736_row16_col0" class="data row16 col0" >14700</td>
#       <td id="T_13736_row16_col1" class="data row16 col1" >제품</td>
#       <td id="T_13736_row16_col2" class="data row16 col2" >18,750,501,902</td>
#     </tr>
#     <tr>
#       <th id="T_13736_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_13736_row17_col0" class="data row17 col0" >14900</td>
#       <td id="T_13736_row17_col1" class="data row17 col1" >원재료</td>
#       <td id="T_13736_row17_col2" class="data row17 col2" >3,768,313,170</td>
#     </tr>
#     <tr>
#       <th id="T_13736_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_13736_row18_col0" class="data row18 col0" >15200</td>
#       <td id="T_13736_row18_col1" class="data row18 col1" >부재료</td>
#       <td id="T_13736_row18_col2" class="data row18 col2" >2,220,619,678</td>
#     </tr>
#     <tr>
#       <th id="T_13736_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_13736_row19_col0" class="data row19 col0" >15700</td>
#       <td id="T_13736_row19_col1" class="data row19 col1" >재공품</td>
#       <td id="T_13736_row19_col2" class="data row19 col2" >18,490,075,556</td>
#     </tr>
#     <tr>
#       <th id="T_13736_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_13736_row20_col0" class="data row20 col0" >17600</td>
#       <td id="T_13736_row20_col1" class="data row20 col1" >장기성예금</td>
#       <td id="T_13736_row20_col2" class="data row20 col2" >289,656,004</td>
#     </tr>
#     <tr>
#       <th id="T_13736_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_13736_row21_col0" class="data row21 col0" >17900</td>
#       <td id="T_13736_row21_col1" class="data row21 col1" >종속기업투자</td>
#       <td id="T_13736_row21_col2" class="data row21 col2" >4,610,376,506</td>
#     </tr>
#     <tr>
#       <th id="T_13736_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_13736_row22_col0" class="data row22 col0" >18000</td>
#       <td id="T_13736_row22_col1" class="data row22 col1" >관계기업투자</td>
#       <td id="T_13736_row22_col2" class="data row22 col2" >-19,152,740</td>
#     </tr>
#     <tr>
#       <th id="T_13736_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_13736_row23_col0" class="data row23 col0" >18700</td>
#       <td id="T_13736_row23_col1" class="data row23 col1" >공동기업투자</td>
#       <td id="T_13736_row23_col2" class="data row23 col2" >689,340,592</td>
#     </tr>
#     <tr>
#       <th id="T_13736_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_13736_row24_col0" class="data row24 col0" >18800</td>
#       <td id="T_13736_row24_col1" class="data row24 col1" >장기지급보증금</td>
#       <td id="T_13736_row24_col2" class="data row24 col

# %% [markdown]
# #### ③-a Groupby 된 결과로 합계 DF 만들기

# %%
# 각 그룹의 차변대변금액 합계를 DF로 변환
df_tb = pd.DataFrame({
    '빈도': groupby_df['차변금액'].count(),
    '차변합계': groupby_df['차변금액'].sum(),
    '대변합계': groupby_df['대변금액'].sum(),
})

# 모양 출력해보기
print(df_tb.head())

# 계정코드와 계정과목으로 묶여있는 인덱스 풀어주기
df_tb.reset_index().head()
# Out:
#                   빈도          차변합계          대변합계
# 계정코드  계정과목
# 10100 현금         166     367803972     323227674
# 10300 보통예금      2169  117268900714  116469441606
# 10301 보통예금         2     449982824             0
# 10400 제예금         35   12995303982   10460000000
# 10600 기타단기금융상품     1             0      14172728
#     계정코드      계정과목    빈도          차변합계          대변합계
# 0  10100        현금   166     367803972     323227674
# 1  10300      보통예금  2169  117268900714  116469441606
# 2  10301      보통예금     2     449982824             0
# 3  10400       제예금    35   12995303982   10460000000
# 4  10600  기타단기금융상품     1             0      14172728

# %% [markdown]
# #### ③-c 잔액 칼럼 삽입

# %% [markdown]
# ##### cf. Apply 사용하는 경우

# %%
# DF에서는 map대신 apply를 사용함
df_tb['차변잔액'] = df_tb.apply(lambda row: row['차변합계'] - row['대변합계'] if row['차변합계'] - row['대변합계'] > 0 else 0, 
                            axis=1) # axis=1은 행 단위(열방향)로 적용

df_tb['대변잔액'] = df_tb.apply(lambda row: row['대변합계'] - row['차변합계'] if row['대변합계'] - row['차변합계'] > 0 else 0, 
                            axis=1) # axis=1은 행 단위(열방향)로 적용

df_tb
# Out:
#                      빈도          차변합계          대변합계        차변잔액      대변잔액
# 계정코드  계정과목
# 10100 현금            166     367803972     323227674    44576298         0
# 10300 보통예금         2169  117268900714  116469441606   799459108         0
# 10301 보통예금            2     449982824             0   449982824         0
# 10400 제예금            35   12995303982   10460000000  2535303982         0
# 10600 기타단기금융상품        1             0      14172728           0  14172728
# ...                 ...           ...           ...         ...       ...
# 95000 유형자산처분손실        1          2000             0        2000         0
# 95600 지분법  평가  손실    19    2625267178             0  2625267178         0
# 95800 무형자산손상차손        1     117333334             0   117333334         0
# 96000 잡손실            14       1492672             0     1492672         0
# 99800 법인세비용           1     163954200             0   163954200         0
#
# [159 rows x 5 columns]

# %% [markdown]
# ##### list comprehenstion 사용 (성능 최적화)

# %%
df_tb['차변잔액'] = [(i[0] - i[1]) if i[0] - i[1] > 0 else 0 for i in zip(df_tb['차변합계'], df_tb['대변합계'])]
df_tb['대변잔액'] = [(i[1] - i[0]) if i[1] - i[0] > 0 else 0 for i in zip(df_tb['차변합계'], df_tb['대변합계'])]

# 또는 ②에서 한 것 처럼 벡터연산을 해도 되는데 나중에 한번 해볼 것

df_tb
# Out:
#                      빈도          차변합계          대변합계        차변잔액      대변잔액
# 계정코드  계정과목
# 10100 현금            166     367803972     323227674    44576298         0
# 10300 보통예금         2169  117268900714  116469441606   799459108         0
# 10301 보통예금            2     449982824             0   449982824         0
# 10400 제예금            35   12995303982   10460000000  2535303982         0
# 10600 기타단기금융상품        1             0      14172728           0  14172728
# ...                 ...           ...           ...         ...       ...
# 95000 유형자산처분손실        1          2000             0        2000         0
# 95600 지분법  평가  손실    19    2625267178             0  2625267178         0
# 95800 무형자산손상차손        1     117333334             0   117333334         0
# 96000 잡손실            14       1492672             0     1492672         0
# 99800 법인세비용           1     163954200             0   163954200         0
#
# [159 rows x 5 columns]
